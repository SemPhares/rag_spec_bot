# %%
from deepeval import evaluate
from deepeval import assert_test
from deepeval.test_case import LLMTestCase
from deepeval.metrics import (
    ContextualPrecisionMetric,
    ContextualRecallMetric,
    ContextualRelevancyMetric,
    AnswerRelevancyMetric,
    FaithfulnessMetric
)

# %%
from ragas import evaluate

# %%
def test_answer_relevancy():
    answer_relevancy_metric = AnswerRelevancyMetric(threshold=0.5)
    test_case = LLMTestCase(
        input="What if these shoes don't fit?",
        # Replace this with the actual output of your LLM application
        actual_output="We offer a 30-day full refund at no extra cost."
    )
    assert_test(test_case, [answer_relevancy_metric])

# %%
test_case = LLMTestCase(
    input="I'm on an F-1 visa, gow long can I stay in the US after graduation?",
    actual_output="You can stay up to 30 days after completing your degree.",
    expected_output="You can stay up to 60 days after completing your degree.",
    retrieval_context=[
        """If you are in the U.S. on an F-1 visa, you are allowed to stay for 60 days after completing
        your degree, unless you have applied for and been approved to participate in OPT."""
    ]
)

# %%
contextual_precision = ContextualPrecisionMetric()
contextual_recall = ContextualRecallMetric()
contextual_relevancy = ContextualRelevancyMetric()

answer_relevancy = AnswerRelevancyMetric()
faithfulness = FaithfulnessMetric()

# %%
contextual_precision.measure(test_case)
print("Score: ", contextual_precision.score)
print("Reason: ", contextual_precision.reason)

contextual_recall.measure(test_case)
print("Score: ", contextual_recall.score)
print("Reason: ", contextual_recall.reason)

contextual_relevancy.measure(test_case)
print("Score: ", contextual_relevancy.score)
print("Reason: ", contextual_relevancy.reason)

# %%
evaluate(
    test_cases=[test_case],
    metrics=[contextual_precision, contextual_recall, contextual_relevancy]
)

evaluate(
    test_cases=[test_case],
    metrics=[answer_relevancy, faithfulness]
)

# %%
from deepeval.metrics import GEval
from deepeval.test_case import LLMTestCaseParams


dark_humor = GEval(
    name="Dark Humor",
    criteria="Determine how funny the dark humor in the actual output is",
    evaluation_params=[LLMTestCaseParams.ACTUAL_OUTPUT],
)

dark_humor.measure(test_case)
print("Score: ", dark_humor.score)
print("Reason: ", dark_humor.reason)




evaluate(
    test_cases=test_case,
    metrics=[
        contextual_precision,
        contextual_recall,
        contextual_relevancy,
        answer_relevancy,
        faithfulness,
        # Optionally include any custom metrics
        dark_humor
    ]
)

# %%
# autoreload

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append("/Users/elsem/Documents/code/rag_spec_bot/specbot")
os.chdir('/Users/elsem/Documents/code/rag_spec_bot')

# %%
from specbot.evaluate.rag_evaluation import Evaluation
from specbot.evaluate.custom_evaluation import evaluation_model
from specbot.evaluate.evaluation_typing import evaluation_input, base_evaluation_input, Result, MetricMetaDonnees
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /opt/miniconda3/envs/rag_env/lib/python3.10/site-packages/deepeval/__init__.py:42: UserWarning: You are using deepeval version 0.21.65, however version 0.21.73 is available. You should consider upgrading via the "pip install --upgrade deepeval" command.
#   warnings.warn(

# %%
test_input = evaluation_input(
    user_input = "I'm on an F-1 visa, gow long can I stay in the US after graduation?",
    actual_output = "You can stay up to 30 days after completing your degree.",
    retrieval_context = [],
    file_name= ['test_file'],
    generation_time= 0.55)

eval_model = evaluation_model(model_name ='ollama')

# %%
eval_llm = Evaluation(test_input = test_input,
                      evaluation_model= eval_model)

# %%
# Convertissez la liste d'instances en une liste de dictionnaires
test_results = [
    Result(
            success=True,
            metrics_metadata=[
                MetricMetaDonnees(
                    metric = 'ContextualPrecisionMetric',
                    threshold = 0.5,
                    success = True,
                    name="Contextual Precision",
                    score=0.8,
                    reason="The model correctly identified the duration of stay as 30 days."
                ),
                MetricMetaDonnees(
                    metric = 'ContextualPrecisionMetric',
                    threshold = 0.5,
                    success = True,
                    name="Contextual Recall",
                    score=0.6,
                    reason="The model did not recall the correct duration of stay."
                ),
                MetricMetaDonnees(
                    metric = 'ContextualPrecisionMetric',
                    threshold = 0.5,
                    success = True,
                    name="Contextual Relevancy",
                    score=0.7,
                    reason="The model's response is relevant to the input."
                )
            ],
            input="I'm on an F-1 visa, gow long can I stay in the US after graduation?",
            actual_output="You can stay up to 30 days after completing your degree.",
            expected_output="You can stay up to 60 days after completing your degree.",
            context=[
                "If you are in the U.S. on an F-1 visa, you are allowed to stay for 60 days after completing your degree, unless you have applied for and been approved to participate in OPT."
            ],
            retrieval_context=[]
        ),
    Result(
            success=True,
            metrics_metadata=[
                MetricMetaDonnees(
                    metric = 'ContextualPrecisionMetric',
                    threshold = 0.5,
                    success = True,
                    name="Contextual Precision",
                    score=0.8,
                    reason="The model correctly identified the duration of stay as 30 days."
                ),
                MetricMetaDonnees(
                    metric = 'ContextualPrecisionMetric',
                    threshold = 0.5,
                    success = True,
                    name="Contextual Recall",
                    score=0.6,
                    reason="The model did not recall the correct duration of stay."
                ),
                MetricMetaDonnees(
                    metric = 'ContextualPrecisionMetric',
                    threshold = 0.5,
                    success = True,
                    name="Contextual Relevancy",
                    score=0.7,
                    reason="The model's response is relevant to the input."
                )
            ],
            input="I'm on an F-1 visa, gow long can I stay in the US after graduation?",
            actual_output="You can stay up to 30 days after completing your degree.",
            expected_output="You can stay up to 60 days after completing your degree.",
            context=[
                "If you are in the U.S. on an F-1 visa, you are allowed to stay for 60 days after completing your degree, unless you have applied for and been approved to participate in OPT."
            ],
            retrieval_context=[]
        ),
    Result(
            success=True,
            metrics_metadata=[
                MetricMetaDonnees(
                    metric = 'ContextualPrecisionMetric',
                    threshold = 0.5,
                    success = True,
                    name="Contextual Precision",
                    score=0.8,
                    reason="The model correctly identified the duration of stay as 30 days."
                ),
                MetricMetaDonnees(
                    metric = 'ContextualPrecisionMetric',
                    threshold = 0.5,
                    success = True,
                    name="Contextual Recall",
                    score=0.6,
                    reason="The model did not recall the correct duration of stay."
                ),
                MetricMetaDonnees(
                    metric = 'ContextualPrecisionMetric',
                    threshold = 0.5,
                    success = True,
                    name="Contextual Relevancy",
                    score=0.7,
                    reason="The model's response is relevant to the input."
                )
            ],
            input="I'm on an F-1 visa, gow long can I stay in the US after graduation?",
            actual_output="You can stay up to 30 days after completing your degree.",
            expected_output="You can stay up to 60 days after completing your degree.",
            context=[
                "If you are in the U.S. on an F-1 visa, you are allowed to stay for 60 days after completing your degree, unless you have applied for and been approved to participate in OPT."
            ],
            retrieval_context=[]
        )
    ]

# %% [markdown]
# for result in test_results:
#     for i, metric_meta in enumerate(result['metrics_metadata']):
#         result.update({"filename_list": "list°filname"})
#         for key, value in vars(metric_meta).items():
#             result.update({f'{key}_{i}': value})
#     del result['metrics_metadata']
#
# for result in test_results :
#     for key, value in vars(current_state).items():
#         result.update({key: value})
# test_results

# %% [markdown]
# for result in test_results_dicts :
#     for key, value in vars(current_state).items():
#         result.update({key: value})
# test_results_dicts

# %%
eval_llm.evaluation(
                    evaluation_mode = "generation",
                    display_mode = "dataframe")
# Out:
# Output()
# Evaluating test cases...
# Event loop is already running. Applying nest_asyncio patch to allow async execution...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ...
#
# Metrics Summary
#
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.5, strict: False, evaluation model: llama3, reason: The score is 1.00 because the response directly addresses your question about staying in the US after graduating with an F-1 visa., error: None)
#
# For test case:
#
#   - input: I'm on an F-1 visa, gow long can I stay in the US after graduation?
#   - actual output: You can stay up to 30 days after completing your degree.
#   - expected output: None
#   - context: None
#   - retrieval context: []
#
# ...
#
# Overall Metric Pass Rates
#
# ...

# %%
from specbot.retriever.doc_transformer import custom_transformer

# %%
custom_transformer.gemini_embeder().embed_query("I'm on an F-1 visa, gow long can I stay in the US after graduation?")
# Out:
# [0.041738134,
#  0.003969785,
#  -0.033584576,
#  -0.024747446,
#  0.01079914,
#  -0.009590016,
#  0.009767357,
#  -0.07417004,
#  0.0100694075,
#  0.020754226,
#  -0.0488794,
#  0.022859043,
#  -0.0023390756,
#  0.0053340946,
#  -0.028951839,
#  -0.013910674,
#  -0.0013128857,
#  -0.023771442,
#  -0.028749518,
#  -0.0049251495,
#  0.0065422403,
#  -0.08762927,
#  0.0015639621,
#  0.003042906,
#  0.025900876,
#  -0.049207196,
#  0.05608589,
#  0.024261503,
#  0.045572363,
#  -0.05304597,
#  0.03793475,
#  -0.0380462,
#  0.040976413,
#  0.045026194,
#  0.035945,
#  0.055108145,
#  -0.027317904,
#  -0.0055684154,
#  -0.013542438,
#  -0.04832462,
#  -0.07048465,
#  -0.032792833,
#  -0.0006987478,
#  0.00897123,
#  -0.012128507,
#  -0.052029435,
#  -0.018024676,
#  0.071224004,
#  -0.014734456,
#  0.043285545,
#  0.08583471,
#  0.017291153,
#  -0.0021592788,
#  -0.014758555,
#  -0.0022561778,
#  -0.03133754,
#  -0.004078226,
#  -0.05983302,
#  -0.017239705,
#  0.0051057837,
# ...

# %%
custom_transformer.llama_cpp_embeder().embed_query("I'm on an F-1 visa, gow long can I stay in the US after graduation?")

# %%
custom_transformer.sentence_embeder().embed_query("I'm on an F-1 visa, gow long can I stay in the US after graduation?")
# Out:
# [-0.01952746883034706,
#  0.010285560041666031,
#  -0.00857212208211422,
#  -0.022426147013902664,
#  0.041561558842659,
#  -0.0233157966285944,
#  -0.02817564085125923,
#  0.035983700305223465,
#  0.0436527319252491,
#  -0.025572819635272026,
#  0.041973426938056946,
#  0.05532404035329819,
#  -0.03192272037267685,
#  -0.04056684672832489,
#  -0.02152022160589695,
#  -0.03743136674165726,
#  -0.04578080028295517,
#  0.007757050450891256,
#  -0.04006889835000038,
#  -0.020839568227529526,
#  0.03711770102381706,
#  -0.03200274705886841,
#  0.005868225824087858,
#  -0.03343610092997551,
#  0.011962483637034893,
#  -0.01831546612083912,
#  -0.03230559453368187,
#  -0.01731954514980316,
#  -0.03774455934762955,
#  -0.04683973267674446,
#  -0.016728967428207397,
#  0.05465756356716156,
#  -0.010464346036314964,
#  -0.035140492022037506,
#  -0.017948055639863014,
#  0.018495457246899605,
#  0.03454595431685448,
#  0.06949461251497269,
#  -0.018621552735567093,
#  0.04833050072193146,
# ...

# %%
from specbot.retriever.vectorstore import retrieve_docs
from langchain_core.documents import Document

# %%
documents = [Document(page_content="If you are in the U.S. on an F-1 visa, you are allowed to stay for 60 days after completing your degree, unless you have applied for and been approved to participate in OPT.",
                       metadata={"source": "https://example.com/faq"}),
            Document(page_content="You can stay up to 30 days after completing your degree.", metadata={"source": "https://example.com/faq"}),
            Document(page_content="If you've applied for OPT, you can extend your stay up to 12 months after graduation.", metadata={"source": "https://example.com/faq"}),
            Document(page_content="STEM graduates can extend their OPT for an additional 24 months, allowing a longer stay.", metadata={"source": "https://example.com/faq"}),
            Document(page_content="Without OPT, the grace period to leave the US is 60 days post-graduation.", metadata={"source": "https://example.com/faq"}),
            Document(page_content="Applying for a work visa after graduation can allow you to stay longer.", metadata={"source": "https://example.com/faq"}),
            Document(page_content="Transitioning to another visa type, like H-1B, is an option for a longer stay.", metadata={"source": "https://example.com/faq"}),
            Document(page_content="You must leave the US within 60 days after your graduation if you don't have OPT or another visa.", metadata={"source": "https://example.com/faq"}),
            Document(page_content="Enrolling in another educational program can extend your F-1 status.", metadata={"source": "https://example.com/faq"}),
            Document(page_content="Participating in academic training related to your field of study can extend your stay.", metadata={"source": "https://example.com/faq"}),
            Document(page_content="Failure to leave the US within the grace period can result in deportation or future entry bans.", metadata={"source": "https://example.com/faq"}),
            ]

# %%
query = "I'm on an F-1 visa, gow long can I stay in the US after graduation?"
retrieve_docs(query, documents)

# %%
query = "resume the text"
retrieve_docs(query, documents)
# Out:
# 2024-07-24 19:59:38,995 - RAG - INFO - Executed extract_category in 0.9126427173614502 seconds
# 2024-07-24 19:59:38,999 - RAG - INFO - Extracted category: SUMMARY
# 2024-07-24 19:59:39,000 - RAG - INFO - Executed wrapper in 0.9183311462402344 seconds
# [Document(page_content='If you are in the U.S. on an F-1 visa, you are allowed to stay for 60 days after completing your degree, unless you have applied for and been approved to participate in OPT.', metadata={'source': 'https://example.com/faq'}),
#  Document(page_content='You can stay up to 30 days after completing your degree.', metadata={'source': 'https://example.com/faq'}),
#  Document(page_content="If you've applied for OPT, you can extend your stay up to 12 months after graduation.", metadata={'source': 'https://example.com/faq'}),
#  Document(page_content='STEM graduates can extend their OPT for an additional 24 months, allowing a longer stay.', metadata={'source': 'https://example.com/faq'}),
# ...
